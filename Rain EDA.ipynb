# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('POWER_SinglePoint_Daily_2000-2021.txt', header= 12, delimiter= '\s+')

# %%
df
# Out:
#        DATE  SRAD  RAIN  RH2M   T2M  TDEW  TMAX  TMIN  WIND
# 0         1  15.9  12.8  85.3  25.8  23.1  28.1  24.0   1.3
# 1         2  18.1  20.3  86.4  25.8  23.3  27.9  24.4   1.3
# 2         3  16.3   8.6  86.6  25.4  23.0  27.3  24.0   1.6
# 3         4  14.3   7.6  87.0  25.2  22.9  26.8  24.1   1.2
# 4         5  13.0   3.3  89.6  25.0  23.1  26.8  23.8   1.9
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 7756  21086  17.5   5.8  84.6  26.2  23.5  28.4  24.2   0.9
# 7757  21087  18.6   5.4  89.5  26.0  24.2  27.5  24.9   1.8
# 7758  21088  16.9  13.6  85.8  26.8  24.2  29.2  24.9   1.9
# 7759  21089  12.1  11.9  86.6  26.5  24.1  28.3  25.3   1.5
# 7760  21090  19.9  41.3  88.7  26.5  24.5  28.2  25.3   3.2
#
# [7761 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5934 entries, 0 to 5933
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    5934 non-null   int64
#  1   SRAD    5934 non-null   float64
#  2   RAIN    5934 non-null   float64
#  3   RH2M    5934 non-null   float64
#  4   T2M     5934 non-null   float64
#  5   TDEW    5934 non-null   float64
#  6   TMAX    5934 non-null   float64
#  7   TMIN    5934 non-null   float64
#  8   WIND    5934 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 417.4 KB

# %%
df['DATE'] = df['DATE']+2000000

# %%
df
# Out:
#          DATE  SRAD  RAIN  RH2M   T2M  TDEW  TMAX  TMIN  WIND
# 0     2000001  15.9  12.8  85.3  25.8  23.1  28.1  24.0   1.3
# 1     2000002  18.1  20.3  86.4  25.8  23.3  27.9  24.4   1.3
# 2     2000003  16.3   8.6  86.6  25.4  23.0  27.3  24.0   1.6
# 3     2000004  14.3   7.6  87.0  25.2  22.9  26.8  24.1   1.2
# 4     2000005  13.0   3.3  89.6  25.0  23.1  26.8  23.8   1.9
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...
# 7756  2021086  17.5   5.8  84.6  26.2  23.5  28.4  24.2   0.9
# 7757  2021087  18.6   5.4  89.5  26.0  24.2  27.5  24.9   1.8
# 7758  2021088  16.9  13.6  85.8  26.8  24.2  29.2  24.9   1.9
# 7759  2021089  12.1  11.9  86.6  26.5  24.1  28.3  25.3   1.5
# 7760  2021090  19.9  41.3  88.7  26.5  24.5  28.2  25.3   3.2
#
# [7761 rows x 9 columns]

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y%j').dt.strftime('%Y-%m-%d')

# %%
df
# Out:
#             DATE  SRAD  RAIN  RH2M   T2M  TDEW  TMAX  TMIN  WIND
# 0     2000-01-01  15.9  12.8  85.3  25.8  23.1  28.1  24.0   1.3
# 1     2000-01-02  18.1  20.3  86.4  25.8  23.3  27.9  24.4   1.3
# 2     2000-01-03  16.3   8.6  86.6  25.4  23.0  27.3  24.0   1.6
# 3     2000-01-04  14.3   7.6  87.0  25.2  22.9  26.8  24.1   1.2
# 4     2000-01-05  13.0   3.3  89.6  25.0  23.1  26.8  23.8   1.9
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...
# 7756  2021-03-27  17.5   5.8  84.6  26.2  23.5  28.4  24.2   0.9
# 7757  2021-03-28  18.6   5.4  89.5  26.0  24.2  27.5  24.9   1.8
# 7758  2021-03-29  16.9  13.6  85.8  26.8  24.2  29.2  24.9   1.9
# 7759  2021-03-30  12.1  11.9  86.6  26.5  24.1  28.3  25.3   1.5
# 7760  2021-03-31  19.9  41.3  88.7  26.5  24.5  28.2  25.3   3.2
#
# [7761 rows x 9 columns]

# %%
df = df.set_index('DATE')

# %%
dt = pd.date_range('2000-01-01', '2021-03-31')
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)

# %%
df.isna().sum()
# Out:
# SRAD    0
# RAIN    0
# RH2M    0
# T2M     0
# TDEW    0
# TMAX    0
# TMIN    0
# WIND    0
# dtype: int64

# %% [markdown]
# ! SRAD     All Sky Insolation Incident on a Horizontal Surface (MJ/m^2/day)<br>
# ! RAIN     Precipitation (mm day-1) <br>
# ! RH2M     Relative Humidity at 2 Meters (%)<br>
# ! T2M     Temperature at 2 Meters (C) <br>
# ! TDEW     Dew/Frost Point at 2 Meters (C)<br>
# ! TMAX     Maximum Temperature at 2 Meters (C) <br>
# ! TMIN     Minimum Temperature at 2 Meters (C) <br>
# ! WIND     Wind Speed at 2 Meters (m/s) <br>
# ! Mean elevation for source NASA/POWER data tile (0.5 x 0.5 grid cell) = 247.24m<br>
# *WEATHER DATA: NASA<br>
# <br>
#  @ INSI   WTHLAT  WTHLONG   WELEV   TAV  AMP  REFHT  WNDHT<br>
#    NASA   -7.791  109.724  247.24  -999                  2

# %%
df
# Out:
#             SRAD  RAIN  RH2M   T2M  TDEW  TMAX  TMIN  WIND
# 2000-01-01  15.9  12.8  85.3  25.8  23.1  28.1  24.0   1.3
# 2000-01-02  18.1  20.3  86.4  25.8  23.3  27.9  24.4   1.3
# 2000-01-03  16.3   8.6  86.6  25.4  23.0  27.3  24.0   1.6
# 2000-01-04  14.3   7.6  87.0  25.2  22.9  26.8  24.1   1.2
# 2000-01-05  13.0   3.3  89.6  25.0  23.1  26.8  23.8   1.9
# ...          ...   ...   ...   ...   ...   ...   ...   ...
# 2021-03-27  17.5   5.8  84.6  26.2  23.5  28.4  24.2   0.9
# 2021-03-28  18.6   5.4  89.5  26.0  24.2  27.5  24.9   1.8
# 2021-03-29  16.9  13.6  85.8  26.8  24.2  29.2  24.9   1.9
# 2021-03-30  12.1  11.9  86.6  26.5  24.1  28.3  25.3   1.5
# 2021-03-31  19.9  41.3  88.7  26.5  24.5  28.2  25.3   3.2
#
# [7761 rows x 8 columns]

# %%
df.plot(figsize = (15, 20), subplots = True, grid = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['RAIN'])

# %%
import seaborn as sns

# %%
g = sns.pairplot(df)

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
top_corr_features = cor.index
sns.heatmap(df[top_corr_features].corr(), annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
data_2020 = df['2018']['RAIN']
data_2020.plot(figsize = (15, 5), grid=True)
# Out:
# <AxesSubplot:>

# %%
data_2020 = df['2019']['RAIN']
data_2020.plot(figsize = (15, 5), grid=True)
# Out:
# <AxesSubplot:>

# %%
data_2020 = df['2020']['RAIN']
data_2020.plot(figsize = (15, 5), grid=True)
# Out:
# <AxesSubplot:>

# %%
data_2020 = df['2021']['RAIN']
data_2020.plot(figsize = (15, 5), grid=True)
# Out:
# <AxesSubplot:>

# %%
tahun_akhir = df['2016':'2021']
tahun_akhir['day_of_month'] = tahun_akhir.index.day
tahun_akhir['day_of_week'] = tahun_akhir.index.dayofweek
tahun_akhir['month'] = tahun_akhir.index.month
tahun_akhir['year'] = tahun_akhir.index.year
# Out:
# <ipython-input-101-35efcf630497>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tahun_akhir['day_of_month'] = tahun_akhir.index.day
# <ipython-input-101-35efcf630497>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tahun_akhir['day_of_week'] = tahun_akhir.index.dayofweek
# <ipython-input-101-35efcf630497>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fig,(ax1, ax2, ax3, ax4)= plt.subplots(nrows=4)
fig.set_size_inches(18, 28)

sns.pointplot(data=tahun_akhir, x='day_of_month', y='RAIN', hue = 'year', ax=ax1)
sns.pointplot(data=tahun_akhir, x='day_of_week', y='RAIN', hue='year', ax=ax2)
sns.pointplot(data=tahun_akhir, x='month', y='RAIN', hue='year', ax=ax3)
sns.pointplot(data=tahun_akhir, x='year', y='RAIN', ax=ax4)
# Out:
# <AxesSubplot:xlabel='year', ylabel='RAIN'>
